# %%
from gensim.models import Word2Vec

# %%
with open('2016_filtered_review.txt', encoding='utf-8') as f:
    docs = [line.strip().split('\t\t') for line in f]
docs1 = [doc[1].strip().split() for doc in docs]

# %%
print(docs1[:3])
# Out:
# [['아니', '딴', '그렇', '비', '비탄', '총', '대체', '왜', '들', '온겨'], ['진심', '쓰레기', '영화', '만들', '무서', '알', '쫄아', '틀었', '이건', '뭐', '웃', '거리', '없는', '쓰레기', '영화', '임'], ['역대', '좀비', '영화', '가장', '최고다', '원작', '만화', '읽어', '보려', '영화', '보고', '결정', '하려', '감독', '간츠', '실사', '했', '사람', '거르려', '그냥', '봤', '정말', '흠잡', '없는', '최고', '좀비', '영화', '잔인', '거', '싫어하지', '참고', '볼', '만하', '로미', '인물', '왜', '그런', '모르']]

# %% [markdown]
# ### sg=1, negative=10 인 경우

# %%
model_sg_n10 = Word2Vec(docs1, window=3, min_count=3, vector_size=100, sg=1, negative=10)
# https://radimrehurek.com/gensim/models/word2vec.html

# %%
model_sg_n10.wv['이정재']
# Out:
# array([-0.07425505,  0.38589188, -0.03259845, -0.48726493, -0.11612929,
#        -0.1421546 ,  0.27515623,  0.18846104,  0.81600475, -0.37393403,
#        -0.07126532, -0.66861427, -0.2665109 ,  0.04404347,  0.05201312,
#        -0.09361747, -0.06910351,  0.04790748, -0.42569044, -0.07261297,
#        -0.19358386,  0.56732994,  0.2199    ,  0.07505177, -0.25615898,
#        -0.26685223, -0.0959332 ,  0.06642775, -0.07825898, -0.24381612,
#         0.18521926,  0.02189109, -0.01352069, -0.13397136, -0.01268043,
#        -0.7005057 , -0.32837138, -0.02807369, -0.36781952,  0.08727583,
#        -0.53193796,  0.37518474, -0.39022186, -0.6384264 , -0.18454182,
#         0.11266179, -0.33870023,  0.05982242, -0.27684566, -0.2156568 ,
#        -0.3358588 , -0.3385564 , -0.0022197 , -0.48186836,  0.35560894,
#         0.24808773, -0.13993964, -0.33243412,  0.06097437,  0.11575813,
#        -0.5214797 , -0.37420705,  0.5238151 , -0.3402935 , -0.62228256,
#        -0.03021877, -0.30843556, -0.20564488,  0.09229241, -0.06320965,
#         0.24239425,  0.01811515, -0.09392752,  0.36872274,  0.6474055 ,
#         0.03929145,  0.05139827, -0.4505146 , -0.40242204, -0.05950831,
#        -0.45884508,  0.19067381, -0.00347869, -0.02689692, -0.04891108,
#        -0.45817453, -0.13160954, -0.3114586 ,  0.7744054 ,  0.20405608,
#         0.5815436 ,  0.11857504,  0.4175246 , -0.0443185 ,  0.65279305,
#         0.30997628, -0.52142733,  0.0065361 ,  0.34345245,  0.24764724],
#       dtype=float32)

# %%
len(model_sg_n10.wv['이정재'])
# Out:
# 100

# %%
import numpy as np

# %%
print(np.dot(model_sg_n10.wv['이정재'], model_sg_n10.wv['이범수'])/(np.linalg.norm(model_sg_n10.wv['이정재'])*np.linalg.norm(model_sg_n10.wv['이범수'])))
# Out:
# 0.82128966

# %%
model_sg_n10.wv.similarity('이정재', '이범수')
# Out:
# 0.82128966

# %%
model_sg_n10.wv.similar_by_word('이정재',topn=50)
# Out:
# [('이범수', 0.8212897181510925),
#  ('공유', 0.8188072443008423),
#  ('송강호', 0.8050479888916016),
#  ('김범수', 0.7780242562294006),
#  ('김남길', 0.7740231156349182),
#  ('조재현', 0.7615543603897095),
#  ('박해일', 0.7497929334640503),
#  ('정우성', 0.7483862638473511),
#  ('이성민', 0.7442755699157715),
#  ('김윤석', 0.7430012226104736),
#  ('김성균', 0.7386887669563293),
#  ('이진욱', 0.7379911541938782),
#  ('황정민', 0.7271596193313599),
#  ('이병헌', 0.7240679264068604),
#  ('주지훈', 0.7218068242073059),
#  ('오지호', 0.7200320959091187),
#  ('마동석', 0.718745231628418),
#  ('정진영', 0.7156891822814941),
#  ('최태준', 0.7133968472480774),
#  ('곽도원', 0.7132660150527954),
#  ('엄지원', 0.7087008953094482),
#  ('요한', 0.7072697281837463),
#  ('공효진', 0.7069131731987),
#  ('조정석', 0.7007834315299988),
#  ('김명민', 0.7002351880073547),
#  ('리암', 0.6980087757110596),
#  ('정재형', 0.6978430151939392),
#  ('공블리', 0.6967376470565796),
#  ('김남일', 0.6964603066444397),
#  ('이재훈', 0.6958767771720886),
#  ('윌스미스', 0.6927394866943359),
#  ('김희원', 0.6903316974639893),
#  ('김성호', 0.6898038983345032),
#  ('조진웅', 0.6879011988639832),
#  ('톰하디', 0.6878861784934998),
#  ('유준상', 0.6867865324020386),
#  ('박철민', 0.6850906610488892),
#  ('김윤식', 0.6844642758369446),
#  ('한지민', 0.6823141574859619),
#  ('차승원', 0.6815618872642517),
#  ('오종혁', 0.6790429353713989),
#  ('류승범', 0.6787063479423523),
#  ('오태경', 0.6786682605743408),
#  ('강원', 0.6780584454536438),
#  ('닐슨', 0.6764675974845886),
#  ('송광호', 0.6753146648406982),
#  ('수역', 0.6750389337539673),
#  ('배성우', 0.6747158169746399),
#  ('견자단', 0.6730107665061951),
#  ('변', 0.6728903651237488)]

# %%
model_sg_n10.wv.similar_by_word('재밌',topn=50)
# Out:
# [('재미있', 0.898267388343811),
#  ('잼남', 0.8369556069374084),
#  ('재밌네', 0.8319281935691833),
#  ('재밋음', 0.827720046043396),
#  ('재밌었', 0.8267784714698792),
#  ('재밌어', 0.8041579127311707),
#  ('재밋엇', 0.7996676564216614),
#  ('재밋어용', 0.7885328531265259),
#  ('잼슴', 0.7873533368110657),
#  ('재미있었', 0.7843563556671143),
#  ('재밋는듯', 0.7800230979919434),
#  ('재밋었음', 0.7765243053436279),
#  ('재밋엇어용', 0.7715973258018494),
#  ('잼난', 0.7688291072845459),
#  ('재밌엇습니', 0.7681296467781067),
#  ('재밌아', 0.7662134766578674),
#  ('재밋었어', 0.7659012079238892),
#  ('재밋게봣', 0.7643240690231323),
#  ('쟈밋', 0.7639384269714355),
#  ('재밋구', 0.762713611125946),
#  ('재밋네', 0.7607937455177307),
#  ('재밋네용', 0.7604079246520996),
#  ('꿀잼임', 0.7602463364601135),
#  ('재밋습니', 0.7597517967224121),
#  ('엇', 0.7592329382896423),
#  ('재밋엇어', 0.75713711977005),
#  ('재미있네', 0.7557938098907471),
#  ('재밋었습니', 0.7555944919586182),
#  ('재밋었', 0.7512845396995544),
#  ('재밌던', 0.7501925230026245),
#  ('재밌슴', 0.7490049600601196),
#  ('재밋엇음', 0.7475301027297974),
#  ('존잼임', 0.7453296780586243),
#  ('재밌더', 0.7444011569023132),
#  ('재밌드', 0.7434653043746948),
#  ('강추임', 0.7416629791259766),
#  ('재미있겠', 0.7410658597946167),
#  ('꿀잼', 0.7409529685974121),
#  ('재밋게봄', 0.7398481965065002),
#  ('재밋습니당', 0.7392673492431641),
#  ('재밋게봣어', 0.7378591299057007),
#  ('재밋게봣습니', 0.7378177642822266),
#  ('재밋습', 0.7374731302261353),
#  ('더재밋', 0.7360031604766846),
#  ('짱재밋어', 0.7355911135673523),
#  ('재밌는', 0.7321880459785461),
#  ('재미있아', 0.7320975065231323),
#  ('재밋게봣음', 0.7320480346679688),
#  ('재밋당', 0.731954038143158),
#  ('재밌고', 0.7313019633293152)]

# %% [markdown]
# ### sg=1, negative=5 인 경우

# %%
model_sg_n5 = Word2Vec(docs1, window=3, min_count=3, vector_size=100, sg=1, negative=5)

# %%
model_sg_n5.wv.similar_by_word('이정재',topn=50)
# Out:
# [('이범수', 0.8182589411735535),
#  ('송강호', 0.8005508184432983),
#  ('공유', 0.7972854375839233),
#  ('조재현', 0.747497022151947),
#  ('김범수', 0.7349443435668945),
#  ('박해일', 0.7274124026298523),
#  ('이병헌', 0.7266798615455627),
#  ('정우성', 0.7201418280601501),
#  ('이성민', 0.7169102430343628),
#  ('김윤석', 0.7062411308288574),
#  ('김남길', 0.7060959339141846),
#  ('곽도원', 0.7021939754486084),
#  ('김명민', 0.7014455199241638),
#  ('조진웅', 0.6993449926376343),
#  ('송광호', 0.6952735185623169),
#  ('리암', 0.695107638835907),
#  ('김성균', 0.6899470090866089),
#  ('박철민', 0.6881530284881592),
#  ('윤제문', 0.6840681433677673),
#  ('범수', 0.6836461424827576),
#  ('마동석', 0.6815115809440613),
#  ('주지훈', 0.6786357760429382),
#  ('최태준', 0.6775581240653992),
#  ('리슨', 0.6753864884376526),
#  ('슨', 0.6750023365020752),
#  ('하정우', 0.6746355891227722),
#  ('오지호', 0.6731645464897156),
#  ('이진욱', 0.6723853945732117),
#  ('제라드', 0.6700780391693115),
#  ('정만식', 0.6691113710403442),
#  ('김윤식', 0.6678562760353088),
#  ('김남일', 0.6677126288414001),
#  ('배성우', 0.66582190990448),
#  ('윌스미스', 0.6650097370147705),
#  ('엄지원', 0.664959728717804),
#  ('김상호', 0.6647025346755981),
#  ('황정민', 0.663810133934021),
#  ('견자단', 0.6637754440307617),
#  ('정재형', 0.6628009080886841),
#  ('공효진', 0.661530613899231),
#  ('유해진', 0.6600908041000366),
#  ('유준상', 0.6599946618080139),
#  ('정진영', 0.6599898934364319),
#  ('니암', 0.6581332087516785),
#  ('김성오', 0.6564258337020874),
#  ('김성호', 0.6564136147499084),
#  ('한지민', 0.6553502678871155),
#  ('오종혁', 0.6549978256225586),
#  ('수역', 0.6531378626823425),
#  ('이재훈', 0.651592493057251)]

# %%
model_sg_n5.wv.similar_by_word('재밌',topn=50)
# Out:
# [('재미있', 0.9174643754959106),
#  ('잼남', 0.835521399974823),
#  ('재밌었', 0.8114217519760132),
#  ('재밌네', 0.81058269739151),
#  ('재밋음', 0.8037752509117126),
#  ('재밌어', 0.7941162586212158),
#  ('잼슴', 0.7635643482208252),
#  ('재밋엇', 0.7632556557655334),
#  ('재밋엇어용', 0.760931670665741),
#  ('재밌아', 0.7600383758544922),
#  ('재미있었', 0.7596234679222107),
#  ('재밋어용', 0.7560392618179321),
#  ('재밋구', 0.752627432346344),
#  ('재밌슴', 0.7493106722831726),
#  ('재밋엇음', 0.7491995096206665),
#  ('재밋었습니', 0.7471035718917847),
#  ('재밋었어', 0.7460206747055054),
#  ('재밋네', 0.7456420063972473),
#  ('재밋었음', 0.7452654838562012),
#  ('쟈밋', 0.7408764958381653),
#  ('엇', 0.7406248450279236),
#  ('재밋엇어', 0.7346155047416687),
#  ('재밋습니', 0.7314833998680115),
#  ('잼난', 0.7312893867492676),
#  ('재밋어', 0.7297465801239014),
#  ('재밋당', 0.7280430197715759),
#  ('재밋게봣습니', 0.7277238965034485),
#  ('재밋게봣', 0.7246276140213013),
#  ('재밋네용', 0.724023699760437),
#  ('재미있네', 0.7227675318717957),
#  ('꾸르잼', 0.7209194302558899),
#  ('재밋었', 0.7206981182098389),
#  ('존잼임', 0.7201669812202454),
#  ('재밋습', 0.7199111580848694),
#  ('재밋게봣어', 0.7190365195274353),
#  ('더재밋', 0.71708744764328),
#  ('재밋엇습니', 0.7163878083229065),
#  ('재밌던', 0.7101749777793884),
#  ('재밋는듯', 0.7040907144546509),
#  ('재밌드', 0.7036056518554688),
#  ('재밌는', 0.7031605243682861),
#  ('재밌았', 0.7023918628692627),
#  ('재밌고', 0.7016664743423462),
#  ('재미나다', 0.7009565830230713),
#  ('꿀잼', 0.6993189454078674),
#  ('재미있더', 0.6955044865608215),
#  ('재밋게봣네', 0.6948491930961609),
#  ('재밋습니당', 0.6944639682769775),
#  ('짱재밋어', 0.6936600208282471),
#  ('짱재밋음', 0.6927710175514221)]

# %% [markdown]
# ### sg=0, negative=10 인 경우

# %%
model_cbow_n10 = Word2Vec(docs1, window=3, min_count=3, vector_size=100, sg=0, negative=10)

# %%
model_cbow_n10.wv.similar_by_word('이정재',topn=50)
# Out:
# [('김윤석', 0.7929652333259583),
#  ('이범수', 0.7816890478134155),
#  ('이진욱', 0.744100034236908),
#  ('조재현', 0.7371965050697327),
#  ('공유', 0.7330566048622131),
#  ('송강호', 0.7284312844276428),
#  ('김범수', 0.7093769311904907),
#  ('주지훈', 0.7074260711669922),
#  ('이성민', 0.7028567790985107),
#  ('요한', 0.7006486058235168),
#  ('박해일', 0.6923685073852539),
#  ('마동석', 0.6904294490814209),
#  ('김남길', 0.6859830021858215),
#  ('조정석', 0.6654824018478394),
#  ('송광호', 0.663470983505249),
#  ('정우성', 0.6614590287208557),
#  ('엄지원', 0.651776909828186),
#  ('이병헌', 0.6472975015640259),
#  ('하정우', 0.6470642685890198),
#  ('곽도원', 0.6434406638145447),
#  ('김영애', 0.6425695419311523),
#  ('강예원', 0.6399478316307068),
#  ('유승호', 0.6395896077156067),
#  ('류승범', 0.6388735771179199),
#  ('김원해', 0.6382673382759094),
#  ('김성오', 0.6353691220283508),
#  ('차승원', 0.6346102952957153),
#  ('김고은', 0.6323971748352051),
#  ('조진웅', 0.6310155391693115),
#  ('윤제문', 0.6297509670257568),
#  ('임시완', 0.6276455521583557),
#  ('김성균', 0.6274002194404602),
#  ('민호', 0.6268581748008728),
#  ('이제훈', 0.6263521909713745),
#  ('김명민', 0.6190758943557739),
#  ('황정민', 0.6187160611152649),
#  ('이희준', 0.6180291771888733),
#  ('톰하디', 0.6152923703193665),
#  ('공효진', 0.614414393901825),
#  ('박철민', 0.613074541091919),
#  ('엄태구', 0.6113646626472473),
#  ('진세연', 0.6078402400016785),
#  ('하시모토', 0.6053761839866638),
#  ('윌스미스', 0.6049310564994812),
#  ('변', 0.6045184135437012),
#  ('남자배우', 0.6018236875534058),
#  ('정진영', 0.6004794239997864),
#  ('휴잭맨', 0.5999574065208435),
#  ('김선아', 0.599711000919342),
#  ('데드샷', 0.5979659557342529)]

# %%
model_cbow_n10.wv.similar_by_word('재밌',topn=50)
# Out:
# [('재미있', 0.9074578285217285),
#  ('재밌네', 0.8194817900657654),
#  ('재밌어', 0.8014765977859497),
#  ('재밋음', 0.8003607392311096),
#  ('재밌었', 0.7868196964263916),
#  ('재미있었', 0.7087598443031311),
#  ('잼남', 0.7033387422561646),
#  ('재밌는', 0.7002300024032593),
#  ('재밋어', 0.6895608305931091),
#  ('재밌더', 0.6871433854103088),
#  ('재밋네', 0.6848909258842468),
#  ('재미있네', 0.6836299896240234),
#  ('재밋엇어', 0.6798540949821472),
#  ('재밌던', 0.6687731146812439),
#  ('재밋', 0.6679466366767883),
#  ('재밋었', 0.6602831482887268),
#  ('재미있어', 0.6591739058494568),
#  ('재밌다', 0.6443008184432983),
#  ('재밋엇음', 0.6348849534988403),
#  ('꿀잼', 0.6343836188316345),
#  ('재밋었어', 0.6327056884765625),
#  ('재밋엇', 0.6306120753288269),
#  ('재미있던', 0.6185398101806641),
#  ('재밌고', 0.617433488368988),
#  ('재미있는', 0.6046621203422546),
#  ('재밌게', 0.6040428876876831),
#  ('잼', 0.6031646728515625),
#  ('재밌구', 0.5995064973831177),
#  ('재밋었음', 0.5833634734153748),
#  ('웃김', 0.5802904367446899),
#  ('재미있더', 0.5482041835784912),
#  ('재미있다', 0.5466857552528381),
#  ('재밋습니', 0.5466854572296143),
#  ('재미있고', 0.544616162776947),
#  ('존잼', 0.5413831472396851),
#  ('재미나', 0.5346218347549438),
#  ('재미있게', 0.5325543880462646),
#  ('웃겼', 0.5261331796646118),
#  ('개꿀잼', 0.5260080099105835),
#  ('재밌으', 0.5214887261390686),
#  ('괜찮', 0.5202298164367676),
#  ('무서웜', 0.5104575157165527),
#  ('재밋었습니', 0.5098888278007507),
#  ('멋있', 0.5084253549575806),
#  ('재밋어용', 0.5073341727256775),
#  ('재미없', 0.4947068989276886),
#  ('재밋습', 0.48791491985321045),
#  ('재밌겠', 0.4854128658771515),
#  ('핵꿀잼', 0.4845306873321533),
#  ('졸잼', 0.4808366000652313)]

# %% [markdown]
# ### sg=0, negative=5 인 경우

# %%
model_cbow_n5 = Word2Vec(docs1, window=3, min_count=3, vector_size=100, sg=0, negative=5)

# %%
model_cbow_n5.wv.similar_by_word('재밌',topn=50)
# Out:
# [('재미있', 0.9023100733757019),
#  ('재밌네', 0.8050611019134521),
#  ('재밋음', 0.7946347594261169),
#  ('재밌었', 0.7928932905197144),
#  ('재밌어', 0.7901458144187927),
#  ('재밋어', 0.732599675655365),
#  ('재밌는', 0.7234867215156555),
#  ('재미있었', 0.7229844927787781),
#  ('재미있네', 0.7166047692298889),
#  ('재밌더', 0.7018826603889465),
#  ('재밌던', 0.7014279365539551),
#  ('잼남', 0.7002723217010498),
#  ('재미있어', 0.6910179257392883),
#  ('재밋엇어', 0.6894341111183167),
#  ('재밋네', 0.6796433925628662),
#  ('재밋', 0.6788340210914612),
#  ('재밌다', 0.6564843058586121),
#  ('꿀잼', 0.6511212587356567),
#  ('재밌고', 0.6444098353385925),
#  ('재밋었', 0.6390551328659058),
#  ('재미있는', 0.6290614604949951),
#  ('재미있던', 0.6261984705924988),
#  ('재밌게', 0.6247260570526123),
#  ('재밋엇', 0.6245548725128174),
#  ('재밋엇음', 0.6098753809928894),
#  ('재밋었어', 0.6078450679779053),
#  ('재미있다', 0.6033551096916199),
#  ('잼', 0.5992617607116699),
#  ('재밌구', 0.5970764756202698),
#  ('웃김', 0.5811483860015869),
#  ('재미있고', 0.5795162916183472),
#  ('재밋었음', 0.5765947103500366),
#  ('개꿀잼', 0.5703247785568237),
#  ('재밋습니', 0.5695359110832214),
#  ('재미있게', 0.5649236440658569),
#  ('재밌으', 0.5636006593704224),
#  ('존잼', 0.554614245891571),
#  ('재미나', 0.5502104163169861),
#  ('재미있겠', 0.5461368560791016),
#  ('재미없', 0.5454018115997314),
#  ('재밌겠', 0.5303983688354492),
#  ('괜찮', 0.5175296664237976),
#  ('재미있더', 0.514354944229126),
#  ('웃겼', 0.5135136842727661),
#  ('무서웠', 0.507489025592804),
#  ('만족스러웠', 0.5020735263824463),
#  ('무서', 0.5004368424415588),
#  ('재밋어용', 0.49778902530670166),
#  ('핵꿀잼', 0.48786959052085876),
#  ('멋있', 0.4808870851993561)]

# %%
model_sg_n10.wv['우주사계']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6748/3041088636.py in <module>
# ----> 1 model_sg_n10.wv['우주사계']
#
# ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in __getitem__(self, key_or_keys)
#     402         """
#     403         if isinstance(key_or_keys, _KEY_TYPES):
# --> 404             return self.get_vector(key_or_keys)
#     405
#     406         return vstack([self.get_vector(key) for key in key_or_keys])
#
# ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in get_vector(self, key, norm)
#     445
#     446         """
# --> 447         index = self.get_index(key)
#     448         if norm:
#     449             self.fill_norms()
#
# ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in get_index(self, key, default)
#     419             return default
#     420         else:
# --> 421             raise KeyError(f"Key '{key}' not present")
#     422
#     423     def get_vector(self, key, norm=False):
#
# KeyError: "Key '우주사계' not present"
